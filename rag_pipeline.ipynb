# %%
from pipelines.data_preprocessing import load_text

# %load_ext autoreload
# %autoreload 2

text_url = "https://blog.dzencode.com/ru/illyuziya-kachestva-vash-sayt-idealen-pozdravlyaem-vy-tolko-chto-sozhgli-byudzhet/"
article_text = load_text(text_url)
print(article_text[:300])
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Иллюзия качества: ваш сайт идеален? Поздравляем, вы только что сожгли бюджет
# Почему проекты, которые вызывают “вау”, часто приводят к “ой”
# Представьте. Вы открываете дашборд. Сайт, над которым работали три месяца, — готов. Он безупречен. Он попал в подборку на Awwwards. У него стильная анимация, гла

# %% [markdown]
# chank data

# %%
from pipelines.data_preprocessing import chunk_text, save_chunks_to_jsonl
# %load_ext autoreload
# %autoreload 2
chunks = chunk_text(article_text, chunk_size=512, semantic=False)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from pipelines.embeddings import compute_embeddings
from pipelines.rag_pipeline import build_rag_index
# %load_ext autoreload
# %autoreload 2
chunks_with_embeddings=compute_embeddings(chunks, model_name="all-MiniLM-L6-v2")
save_chunks_to_jsonl(chunks_with_embeddings)
index = build_rag_index(chunks_with_embeddings)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Batches: 100%|██████████| 2/2 [00:03<00:00,  1.60s/it]
# Сгенерировано 37 эмбеддингов, размерность 384
# вњ… RAG-С„Р°Р№Р» СЃРѕС…СЂР°РЅС‘РЅ: artifacts/rag_article.jsonl
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File c:\dzen\venv\Lib\site-packages\httpx\_transports\default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File c:\dzen\venv\Lib\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File c:\dzen\venv\Lib\site-packages\httpcore\_sync\connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#
# File c:\dzen\venv\Lib\site-packages\httpcore\_sync\connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#
# File c:\dzen\venv\Lib\site-packages\httpcore\_sync\connection.py:101, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
# --> 101     raise exc
#     103 return self._connection.handle_request(request)
#
# File c:\dzen\venv\Lib\site-packages\httpcore\_sync\connection.py:78, in HTTPConnection.handle_request(self, request)
#      77 if self._connection is None:
# ---> 78     stream = self._connect(request)
#      80     ssl_object = stream.get_extra_info("ssl_object")
#
# File c:\dzen\venv\Lib\site-packages\httpcore\_sync\connection.py:124, in HTTPConnection._connect(self, request)
#     123 with Trace("connect_tcp", logger, request, kwargs) as trace:
# --> 124     stream = self._network_backend.connect_tcp(**kwargs)
#     125     trace.return_value = stream
#
# File c:\dzen\venv\Lib\site-packages\httpcore\_backends\sync.py:207, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#     202 exc_map: ExceptionMapping = {
#     203     socket.timeout: ConnectTimeout,
#     204     OSError: ConnectError,
#     205 }
# --> 207 with map_exceptions(exc_map):
#     208     sock = socket.create_connection(
#     209         address,
#     210         timeout,
#     211         source_address=source_address,
#     212     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(value)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File c:\dzen\venv\Lib\site-packages\httpcore\_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ConnectError: [WinError 10061] Подключение не установлено, т.к. конечный компьютер отверг запрос на подключение
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# File c:\dzen\venv\Lib\site-packages\qdrant_client\http\api_client.py:134, in ApiClient.send_inner(self, request)
#     133 try:
# --> 134     response = self._client.send(request)
#     135 except Exception as e:
#
# File c:\dzen\venv\Lib\site-packages\httpx\_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#
# File c:\dzen\venv\Lib\site-packages\httpx\_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#
# File c:\dzen\venv\Lib\site-packages\httpx\_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#
# File c:\dzen\venv\Lib\site-packages\httpx\_client.py:1014, in Client._send_single_request(self, request)
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#
# File c:\dzen\venv\Lib\site-packages\httpx\_transports\default.py:249, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
# --> 249 with map_httpcore_exceptions():
#     250     resp = self._pool.handle_request(req)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(value)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File c:\dzen\venv\Lib\site-packages\httpx\_transports\default.py:118, in map_httpcore_exceptions()
#     117 message = str(exc)
# --> 118 raise mapped_exc(message) from exc
#
# ConnectError: [WinError 10061] Подключение не установлено, т.к. конечный компьютер отверг запрос на подключение
#
# During handling of the above exception, another exception occurred:
#
# ResponseHandlingException                 Traceback (most recent call last)
# Cell In[10], line 7
#       5 chunks_with_embeddings=compute_embeddings(chunks, model_name="all-MiniLM-L6-v2")
#       6 save_chunks_to_jsonl(chunks_with_embeddings)
# ----> 7 index = build_rag_index(chunks_with_embeddings)
#
# File c:\dzen\pipelines\rag_pipeline.py:17, in build_rag_index(chunks, collection_name, host, port)
#      14 vector_size = len(chunks[0]["embedding"])
#      16 # Создаём коллекцию (или пересоздаём)
# ---> 17 client.recreate_collection(
#      18     collection_name=collection_name,
#      19     vectors_config=VectorParams(size=vector_size, distance=Distance.COSINE),
#      20 )
#      22 # Подготавливаем данные для вставки
#      23 points = [
#      24     PointStruct(
#      25         id=chunk["id"],  # уникальный ID
#    (...)     34     for chunk in chunks
#      35 ]
#
# File c:\dzen\venv\Lib\site-packages\qdrant_client\qdrant_client.py:2479, in QdrantClient.recreate_collection(self, collection_name, vectors_config, sparse_vectors_config, shard_number, sharding_method, replication_factor, write_consistency_factor, on_disk_payload, hnsw_config, optimizers_config, wal_config, quantization_config, init_from, timeout, strict_mode_config, **kwargs)
#    2470 assert len(kwargs) == 0, f"Unknown arguments: {list(kwargs.keys())}"
#    2472 warnings.warn(
#    2473     "`recreate_collection` method is deprecated and will be removed in the future."
#    2474     " Use `collection_exists` to check collection existence and `create_collection` instead.",
#    2475     DeprecationWarning,
#    2476     stacklevel=2,
#    2477 )
# -> 2479 return self._client.recreate_collection(
#    2480     collection_name=collection_name,
#    2481     vectors_config=vectors_config,
#    2482     shard_number=shard_number,
#    2483     sharding_method=sharding_method,
#    2484     replication_factor=replication_factor,
#    2485     write_consistency_factor=write_consistency_factor,
#    2486     on_disk_payload=on_disk_payload,
#    2487     hnsw_config=hnsw_config,
#    2488     optimizers_config=optimizers_config,
#    2489     wal_config=wal_config,
#    2490     quantization_config=quantization_config,
#    2491     init_from=init_from,
#    2492     timeout=timeout,
#    2493     sparse_vectors_config=sparse_vectors_config,
#    2494     strict_mode_config=strict_mode_config,
#    2495     **kwargs,
#    2496 )
#
# File c:\dzen\venv\Lib\site-packages\qdrant_client\qdrant_remote.py:2843, in QdrantRemote.recreate_collection(self, collection_name, vectors_config, shard_number, replication_factor, write_consistency_factor, on_disk_payload, hnsw_config, optimizers_config, wal_config, quantization_config, init_from, timeout, sparse_vectors_config, sharding_method, strict_mode_config, **kwargs)
#    2824 def recreate_collection(
#    2825     self,
#    2826     collection_name: str,
#    (...)   2841     **kwargs: Any,
#    2842 ) -> bool:
# -> 2843     self.delete_collection(collection_name, timeout=timeout)
#    2845     return self.create_collection(
#    2846         collection_name=collection_name,
#    2847         vectors_config=vectors_config,
#    (...)   2860         strict_mode_config=strict_mode_config,
#    2861     )
#
# File c:\dzen\venv\Lib\site-packages\qdrant_client\qdrant_remote.py:2697, in QdrantRemote.delete_collection(self, collection_name, timeout, **kwargs)
#    2691 if self._prefer_grpc:
#    2692     return self.grpc_collections.Delete(
#    2693         grpc.DeleteCollection(collection_name=collection_name, timeout=timeout),
#    2694         timeout=timeout if timeout is not None else self._timeout,
#    2695     ).result
# -> 2697 result: Optional[bool] = self.http.collections_api.delete_collection(
#    2698     collection_name, timeout=timeout
#    2699 ).result
#    2700 assert result is not None, "Delete collection returned None"
#    2701 return result
#
# File c:\dzen\venv\Lib\site-packages\qdrant_client\http\api\collections_api.py:308, in SyncCollectionsApi.delete_collection(self, collection_name, timeout)
#     300 def delete_collection(
#     301     self,
#     302     collection_name: str,
#     303     timeout: int = None,
#     304 ) -> m.InlineResponse200:
#     305     """
#     306     Drop collection and all associated data
#     307     """
# --> 308     return self._build_for_delete_collection(
#     309         collection_name=collection_name,
#     310         timeout=timeout,
#     311     )
#
# File c:\dzen\venv\Lib\site-packages\qdrant_client\http\api\collections_api.py:123, in _CollectionsApi._build_for_delete_collection(self, collection_name, timeout)
#     120     query_params["timeout"] = str(timeout)
#     122 headers = {}
# --> 123 return self.api_client.request(
#     124     type_=m.InlineResponse200,
#     125     method="DELETE",
#     126     url="/collections/{collection_name}",
#     127     headers=headers if headers else None,
#     128     path_params=path_params,
#     129     params=query_params,
#     130 )
#
# File c:\dzen\venv\Lib\site-packages\qdrant_client\http\api_client.py:95, in ApiClient.request(self, type_, method, url, path_params, **kwargs)
#      93     kwargs["timeout"] = int(kwargs["params"]["timeout"])
#      94 request = self._client.build_request(method, url, **kwargs)
# ---> 95 return self.send(request, type_)
#
# File c:\dzen\venv\Lib\site-packages\qdrant_client\http\api_client.py:112, in ApiClient.send(self, request, type_)
#     111 def send(self, request: Request, type_: Type[T]) -> T:
# --> 112     response = self.middleware(request, self.send_inner)
#     114     if response.status_code == 429:
#     115         retry_after_s = response.headers.get("Retry-After", None)
#
# File c:\dzen\venv\Lib\site-packages\qdrant_client\http\api_client.py:250, in BaseMiddleware.__call__(self, request, call_next)
#     249 def __call__(self, request: Request, call_next: Send) -> Response:
# --> 250     return call_next(request)
#
# File c:\dzen\venv\Lib\site-packages\qdrant_client\http\api_client.py:136, in ApiClient.send_inner(self, request)
#     134     response = self._client.send(request)
#     135 except Exception as e:
# --> 136     raise ResponseHandlingException(e)
#     137 return response
#
# ResponseHandlingException: [WinError 10061] Подключение не установлено, т.к. конечный компьютер отверг запрос на подключение
